# %%
# Import bibliothèque de manipulation de dataframe
import pandas as pd

# Import des bibliothèques de viz
import matplotlib.pyplot as plt
import seaborn as sns

# Import split data
from sklearn.model_selection import train_test_split

# Import modèles de ML Supervisé Régression
from sklearn.linear_model import LinearRegression

# Import modèles de ML Supervisé Classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# Import modèle de ML NON Supervisé
from sklearn.neighbors import NearestNeighbors

# Import des métriques
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# Import outil standardisation de la donnée
from sklearn.preprocessing import StandardScaler

# Import pipeline
from sklearn.pipeline import Pipeline

# Gestion des warnings
import warnings

# %%
file8 = '/Users/kdahm/Desktop/Formation_DATA_Analyst/Projet_2/ImDB/Regroupement/tmdb_full.csv'
df_tmdb = pd.read_csv(file8, sep = ',', low_memory=False)

# %%
df_tmdb.head()
# Out:
#    adult                     backdrop_path  budget  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0
# 1  False                               NaN       0
# 2  False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 3  False  /hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg       0
# 4  False  /l94l89eMmFKh7na2a1u5q67VgNx.jpg       0
#
#                            genres homepage    id    imdb_id original_language  \
# 0                      ['Comedy']      NaN  3924  tt0029927                en
# 1                   ['Adventure']      NaN  6124  tt0011436                de
# 2            ['Drama', 'Romance']      NaN  8773  tt0055747                fr
# 3    ['Drama', 'Comedy', 'Crime']      NaN     2  tt0094675                fi
# 4  ['Drama', 'Comedy', 'Romance']      NaN     3  tt0092149                fi
#
#          original_title                                           overview  \
# 0               Blondie  Blondie and Dagwood are about to celebrate the...
# ...

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309572 entries, 0 to 309571
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   adult                         309572 non-null  bool
#  1   backdrop_path                 151760 non-null  object
#  2   budget                        309572 non-null  int64
#  3   genres                        309572 non-null  object
#  4   homepage                      44262 non-null   object
#  5   id                            309572 non-null  int64
#  6   imdb_id                       309572 non-null  object
#  7   original_language             309572 non-null  object
#  8   original_title                309572 non-null  object
#  9   overview                      282512 non-null  object
#  10  popularity                    309572 non-null  float64
#  11  poster_path                   264159 non-null  object
# ...

# %%
df_tmdb = df_tmdb.drop(['id','production_countries','original_language','tagline','production_companies_country','homepage','spoken_languages'], axis = 1)

# %%
df_tmdb.head()
# Out:
#    adult                     backdrop_path  budget  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0
# 1  False                               NaN       0
# 2  False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 3  False  /hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg       0
# 4  False  /l94l89eMmFKh7na2a1u5q67VgNx.jpg       0
#
#                            genres    imdb_id        original_title  \
# 0                      ['Comedy']  tt0029927               Blondie
# 1                   ['Adventure']  tt0011436   Der Mann ohne Namen
# 2            ['Drama', 'Romance']  tt0055747   L'Amour à vingt ans
# 3    ['Drama', 'Comedy', 'Crime']  tt0094675                 Ariel
# 4  ['Drama', 'Comedy', 'Romance']  tt0092149  Varjoja paratiisissa
#
#                                             overview  popularity  \
# 0  Blondie and Dagwood are about to celebrate the...       2.852
# 1                                                NaN       1.091
# ...

# %%
df_tmdb['status'].unique()
# Out:
# array(['Released', 'In Production', 'Post Production', 'Canceled',
#        'Planned', 'Rumored'], dtype=object)

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309572 entries, 0 to 309571
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   adult                      309572 non-null  bool
#  1   backdrop_path              151760 non-null  object
#  2   budget                     309572 non-null  int64
#  3   genres                     309572 non-null  object
#  4   imdb_id                    309572 non-null  object
#  5   original_title             309572 non-null  object
#  6   overview                   282512 non-null  object
#  7   popularity                 309572 non-null  float64
#  8   poster_path                264159 non-null  object
#  9   release_date               301339 non-null  object
#  10  revenue                    309572 non-null  int64
#  11  runtime                    309572 non-null  int64
#  12  status                     309572 non-null  object
# ...

# %%
df_tmdb = df_tmdb.loc[(df_tmdb['status'] == 'Released')]

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 306291 entries, 0 to 309570
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   adult                      306291 non-null  bool
#  1   backdrop_path              151137 non-null  object
#  2   budget                     306291 non-null  int64
#  3   genres                     306291 non-null  object
#  4   imdb_id                    306291 non-null  object
#  5   original_title             306291 non-null  object
#  6   overview                   279685 non-null  object
#  7   popularity                 306291 non-null  float64
#  8   poster_path                262445 non-null  object
#  9   release_date               300553 non-null  object
#  10  revenue                    306291 non-null  int64
#  11  runtime                    306291 non-null  int64
#  12  status                     306291 non-null  object
# ...

# %%
df_tmdb['poster_path'] = df_tmdb['poster_path'].fillna(df_tmdb['backdrop_path'])

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 306291 entries, 0 to 309570
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   adult                      306291 non-null  bool
#  1   backdrop_path              151137 non-null  object
#  2   budget                     306291 non-null  int64
#  3   genres                     306291 non-null  object
#  4   imdb_id                    306291 non-null  object
#  5   original_title             306291 non-null  object
#  6   overview                   279685 non-null  object
#  7   popularity                 306291 non-null  float64
#  8   poster_path                263788 non-null  object
#  9   release_date               300553 non-null  object
#  10  revenue                    306291 non-null  int64
#  11  runtime                    306291 non-null  int64
#  12  status                     306291 non-null  object
# ...

# %%
df_tmdb = df_tmdb.loc[~df_tmdb['poster_path'].isna()]

# %%
df_tmdb = df_tmdb.drop('backdrop_path', axis = 1)

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263788 entries, 0 to 309570
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   adult                      263788 non-null  bool
#  1   budget                     263788 non-null  int64
#  2   genres                     263788 non-null  object
#  3   imdb_id                    263788 non-null  object
#  4   original_title             263788 non-null  object
#  5   overview                   245015 non-null  object
#  6   popularity                 263788 non-null  float64
#  7   poster_path                263788 non-null  object
#  8   release_date               261337 non-null  object
#  9   revenue                    263788 non-null  int64
#  10  runtime                    263788 non-null  int64
#  11  status                     263788 non-null  object
#  12  title                      263788 non-null  object
# ...

# %%
df_tmdb.to_csv('/Users/kdahm/Desktop/Formation_DATA_Analyst/Projet_2/ImDB/Regroupement/TMDB_cleaned.csv', sep = '\t', index = False)
